# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:\\Users\\hp\\Desktop\\amala\\Bank Customer Churn Prediction.csv")
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       credit_card  active_member  estimated_salary  churn
# ...

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'credit_card', 'active_member', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
df.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        credit_card  active_member  estimated_salary         churn
# count  10000.00000   10000.000000      10000.000000  10000.000000
# mean       0.70550       0.515100     100090.239881      0.203700
# std        0.45584       0.499797      57510.492818      0.402769
# ...

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="autumn")
# Out:
# <AxesSubplot:>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# customer_id         10000
# credit_score          460
# country                 3
# gender                  2
# age                    70
# tenure                 11
# balance              6382
# credit_card             2
# active_member           2
# estimated_salary     9999
# churn                   2
# dtype: int64

# %%
df['customer_id'].value_counts()
# Out:
# 15634602    1
# 15667932    1
# 15766185    1
# 15667632    1
# 15599024    1
#            ..
# 15599078    1
# 15702300    1
# 15660735    1
# 15671390    1
# 15628319    1
# Name: customer_id, Length: 10000, dtype: int64

# %%
df['credit_score'].value_counts()
# Out:
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: credit_score, Length: 460, dtype: int64

# %%
df['country'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: country, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: gender, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: age, Length: 70, dtype: int64

# %%
df['tenure'].value_counts()
# Out:
# 2     1048
# 1     1035
# 7     1028
# 8     1025
# 5     1012
# 3     1009
# 4      989
# 9      984
# 6      967
# 10     490
# 0      413
# Name: tenure, dtype: int64

# %%
df['balance'].value_counts()
# Out:
# 0.00         3617
# 130170.82       2
# 105473.74       2
# 85304.27        1
# 159397.75       1
#              ...
# 81556.89        1
# 112687.69       1
# 108698.96       1
# 238387.56       1
# 130142.79       1
# Name: balance, Length: 6382, dtype: int64

# %%
df['credit_card'].value_counts()
# Out:
# 1    7055
# 0    2945
# Name: credit_card, dtype: int64

# %%
df['active_member'].value_counts()
# Out:
# 1    5151
# 0    4849
# Name: active_member, dtype: int64

# %%
df['estimated_salary'].value_counts()
# Out:
# 24924.92     2
# 101348.88    1
# 55313.44     1
# 72500.68     1
# 182692.80    1
#             ..
# 120893.07    1
# 188377.21    1
# 55902.93     1
# 4523.74      1
# 38190.78     1
# Name: estimated_salary, Length: 9999, dtype: int64

# %%
df['churn'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: churn, dtype: int64

# %%
df['churn'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10, 6))
df['country'].value_counts().plot(kind='bar')
plt.xlabel('Counrties Names')
plt.ylabel('Numbers of Customers')
plt.title("Comparsion betweeen Countries and Customers")
# Out:
# Text(0.5, 1.0, 'Comparsion betweeen Countries and Customers')

# %%
plt.figure(figsize=(10, 6))
df['gender'].value_counts().plot(kind='bar')
plt.xlabel('gender')
plt.ylabel('Numbers of Customers')
plt.title("Comparsion betweeen Genders")
# Out:
# Text(0.5, 1.0, 'Comparsion betweeen Genders')

# %%
sns.lmplot(x='age',y='estimated_salary',data=df,hue='gender',palette='Set1',
           markers=['o','v'],scatter_kws={'s':80})

# %%
sns.lmplot(x='age',y='estimated_salary',data=df,row='gender', col = 'country')

# %%
sns.countplot(x='country',data=df,hue = 'gender',palette='Set1')
# Out:
# <AxesSubplot:xlabel='country', ylabel='count'>

# %%
country=df['country']
gender=df['gender']
churn=df['churn']

# %%
fig,axes=plt.subplots(1,2,figsize=(30,10))
fig.suptitle('vusualising categorical data columns')
sns.barplot(x=country,y=churn,ax=axes[0])
sns.barplot(x=gender,y=churn,ax=axes[1])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='churn'>

# %%
sns.set_style("whitegrid")
sns.pairplot(df)

# %%
df.corr()
# Out:
#                   customer_id  credit_score       age    tenure   balance  \
# customer_id          1.000000      0.005308  0.009497 -0.014883 -0.012419
# credit_score         0.005308      1.000000 -0.003965  0.000842  0.006268
# age                  0.009497     -0.003965  1.000000 -0.009997  0.028308
# tenure              -0.014883      0.000842 -0.009997  1.000000 -0.012254
# balance             -0.012419      0.006268  0.028308 -0.012254  1.000000
# credit_card         -0.014025     -0.005458 -0.011721  0.022583 -0.014858
# active_member        0.001665      0.025651  0.085472 -0.028362 -0.010084
# estimated_salary     0.015271     -0.001384 -0.007201  0.007784  0.012797
# churn               -0.006248     -0.027094  0.285323 -0.014001  0.118533
#
#                   credit_card  active_member  estimated_salary     churn
# customer_id         -0.014025       0.001665          0.015271 -0.006248
# credit_score        -0.005458       0.025651         -0.001384 -0.027094
# ...

# %%
plt.figure(figsize=(15,6))
corrmap = df.corr()
top=corrmap.index
g=sns.heatmap(df[top].corr(),annot=True,cmap="RdYlGn")
plt.title("correlation between the columns")
plt.show()

# %%
df= pd.get_dummies(df, columns= ['country', 'gender'], drop_first=True)
df
# Out:
#       customer_id  credit_score  age  tenure    balance  credit_card  \
# 0        15634602           619   42       2       0.00            1
# 1        15647311           608   41       1   83807.86            0
# 2        15619304           502   42       8  159660.80            1
# 3        15701354           699   39       1       0.00            0
# 4        15737888           850   43       2  125510.82            1
# ...           ...           ...  ...     ...        ...          ...
# 9995     15606229           771   39       5       0.00            1
# 9996     15569892           516   35      10   57369.61            1
# 9997     15584532           709   36       7       0.00            0
# 9998     15682355           772   42       3   75075.31            1
# 9999     15628319           792   28       4  130142.79            1
#
#       active_member  estimated_salary  churn  country_Germany  country_Spain  \
# ...

# %%
X=df.drop(columns=['churn'])
y=df['churn']

# %%
X.head()
# Out:
#    customer_id  credit_score  age  tenure    balance  credit_card  \
# 0     15634602           619   42       2       0.00            1
# 1     15647311           608   41       1   83807.86            0
# 2     15619304           502   42       8  159660.80            1
# 3     15701354           699   39       1       0.00            0
# 4     15737888           850   43       2  125510.82            1
#
#    active_member  estimated_salary  country_Germany  country_Spain  \
# 0              1         101348.88                0              0
# 1              1         112542.58                0              1
# 2              0         113931.57                0              0
# 3              0          93826.63                0              0
# 4              1          79084.10                0              1
#
#    gender_Male
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

model_log=LogisticRegression()

# %%
model_log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_log=model_log.predict(X_test)
pred_log
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
print(classification_report(y_test,pred_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89      2416
#            1       0.00      0.00      0.00       584
#
#     accuracy                           0.81      3000
#    macro avg       0.40      0.50      0.45      3000
# weighted avg       0.65      0.81      0.72      3000

# %%
print(accuracy_score(y_test,pred_log))
# Out:
# 0.8053333333333333

# %%
print(confusion_matrix(y_test,pred_log))
# Out:
# [[2416    0]
#  [ 584    0]]

# %% [markdown]
# # 1.knn-algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn_cl = KNeighborsClassifier(11)

# %%
model_knn_cl.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
pred=model_knn_cl.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89      2416
#            1       0.27      0.03      0.05       584
#
#     accuracy                           0.80      3000
#    macro avg       0.54      0.50      0.47      3000
# weighted avg       0.70      0.80      0.72      3000

# %%
print(accuracy_score(y_test,pred))
# Out:
# 0.7963333333333333

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[2373   43]
#  [ 568   16]]

# %% [markdown]
# # 2.XGboost algorithm

# %%
import xgboost

# %%
from xgboost import XGBClassifier

# %%
model=XGBClassifier(objective="binary:logistic", random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=42,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      2416
#            1       0.62      0.39      0.48       584
#
#     accuracy                           0.83      3000
#    macro avg       0.74      0.66      0.69      3000
# weighted avg       0.82      0.83      0.82      3000

# %%
print(accuracy_score(y_test,pred))
# Out:
# 0.8336666666666667

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[2275  141]
#  [ 358  226]]
